# %%
pip install torch==1.4+cu100 torchvision==0.5.0+cu100 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.4+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torch-1.4.0%2Bcu100-cp36-cp36m-linux_x86_64.whl (723.9MB)
#      |████████████████████████████████| 723.9MB 25kB/s
# Collecting torchvision==0.5.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torchvision-0.5.0%2Bcu100-cp36-cp36m-linux_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.1MB 51.6MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (1.18.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.6.0+cu101
#     Uninstalling torch-1.6.0+cu101:
#       Successfully uninstalled torch-1.6.0+cu101
#   Found existing installation: torchvision 0.7.0+cu101
#     Uninstalling torchvision-0.7.0+cu101:
#       Successfully uninstalled torchvision-0.7.0+cu101
# Successfully installed torch-1.4.0+cu100 torchvision-0.5.0+cu100

# %%
# %pwd
# Out:
# '/content'

# %%
# !git clone https://www.github.com/nvidia/apex
# %cd apex 
# !python setup.py install --cuda_ext --cpp_ext
# %pwd
# !pip install omegaconf
# !pip install torch-mimicry
# Out:
# Cloning into 'apex'...
# warning: redirecting to https://github.com/nvidia/apex.git/
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7449 (delta 0), reused 2 (delta 0), pack-reused 7443
# Receiving objects: 100% (7449/7449), 13.91 MiB | 28.21 MiB/s, done.
# Resolving deltas: 100% (5029/5029), done.
# /content/apex
#
#
# torch.__version__  = 1.4.0+cu100
#
#
# setup.py:67: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#   warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
#
# Compiling cuda extensions with
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
# from /usr/local/cuda/bin
#
# Traceback (most recent call last):
#   File "setup.py", line 152, in <module>
#     check_cuda_torch_binary_vs_bare_metal(torch.utils.cpp_extension.CUDA_HOME)
#   File "setup.py", line 106, in check_cuda_torch_binary_vs_bare_metal
#     "https://github.com/NVIDIA/apex/pull/323#discussion_r287021798.  "
# RuntimeError: Cuda extensions are being compiled with a version of Cuda that does not match the version used to compile Pytorch binaries.  Pytorch binaries were compiled with Cuda 10.0.
# In some cases, a minor-version mismatch will not cause later errors:  https://github.com/NVIDIA/apex/pull/323#discussion_r287021798.  You can try commenting out this check (at your own risk).

# %%
# import hydra
from omegaconf import DictConfig
import torch
import torch.optim as optim
import torch_mimicry as mmc
from apex import amp

# %%
from models.unetgan_32 import UNetDiscriminator,UNetGenerator

# %%
# get original path
# cwd = hydra.utils.get_original_cwd()
# DATASET_DIR = cwd + "/" + cfg.dataset.dataset_dir

# Data handling objects
device = torch.device('cuda:0' if torch.cuda.is_available() else "cpu")
# dataset = mmc.datasets.load_dataset(root=DATASET_DIR,
#                                     name=cfg.dataset.dataset_name)
dataset = mmc.datasets.load_dataset(root="dataset",
                                    name="cifar10")
# dataloader = torch.utils.data.DataLoader(
#     dataset,
#     batch_size=cfg.training.batch_size,
#     shuffle=True,
#     num_workers=cfg.training.num_workers)
dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=64,
    shuffle=True,
    num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to dataset/cifar10/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting dataset/cifar10/cifar-10-python.tar.gz to dataset/cifar10

# %%
cfg = None
# Define models and optimizers
netG = UNetGenerator(nz=128, ngf=256, loss_type="ns",  is_amp=False)

netD = UNetDiscriminator(ndf=128, loss_type="ns",is_amp=False)

netG, netD = netG.to(device), netD.to(device)

# optD = optim.Adam(netD.parameters(),
#                   cfg.optimizer.lrD,
#                   betas=(cfg.optimizer.beta1, cfg.optimizer.beta2))
# optG = optim.Adam(netG.parameters(),
#                   cfg.optimizer.lrG,
#                   betas=(cfg.optimizer.beta1, cfg.optimizer.beta2))
optD = optim.Adam(netD.parameters(),
                  0.0002,
                  betas=(0.0, 0.9))
optG = optim.Adam(netG.parameters(),
                  0.0002,
                  betas=(0.0, 0.9))

print(device)
# if cfg.training.is_amp:
#     [netG, netD], [optG, optD] = amp.initialize([netG, netD],
#                                                 [optG, optD],
#                                                 opt_level=cfg.training.opt_level)
# Out:
# cuda:0

# %%
[netG, netD], [optG, optD] = amp.initialize([netG, netD], [optG, optD], opt_level="O0")
# Out:
# Selected optimization level O0:  Pure FP32 training.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O0
# cast_model_type        : torch.float32
# patch_torch_functions  : False
# keep_batchnorm_fp32    : None
# master_weights         : False
# loss_scale             : 1.0
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O0
# cast_model_type        : torch.float32
# patch_torch_functions  : False
# keep_batchnorm_fp32    : None
# master_weights         : False
# loss_scale             : 1.0

# %%
trainer = mmc.training.Trainer(
    netD=netD,
    netG=netG,
    optD=optD,
    optG=optG,
    n_dis=5,
    num_steps=100000,
    dataloader=dataloader,
    log_dir="logs",
    device=device)
trainer.train()
# Out:
# Streaming output truncated to the last 5000 lines.
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.7416
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1853 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8385/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.7563
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1750 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8386/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.8428
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1802 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8387/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.5536
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1805 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8388/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.2695
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1781 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8389/100000]
# | D(G(z)): 0.05
# | D(x): 1.0
# | errD: 0.1134
# | errG: 17.924
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1814 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8390/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.9416
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1812 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8391/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.9121
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1863 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8392/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 14.1487
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1841 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8393/100000]
# | D(G(z)): 0.006
# | D(x): 1.0
# | errD: 0.0076
# | errG: 17.3481
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1806 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8394/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.1501
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1789 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8395/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.2008
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1772 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8396/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.4625
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1938 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8397/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.9156
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1779 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8398/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.1531
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1674 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8399/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.6474
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1812 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8400/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.3467
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1816 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8401/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.1968
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1781 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8402/100000]
# | D(G(z)): 0.0001
# | D(x): 1.0
# | errD: 0.0001
# | errG: 16.7805
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1814 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8403/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.9204
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1913 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8404/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.6294
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.2120 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8405/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.8276
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1795 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8406/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.7681
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1869 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8407/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.7651
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1859 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8408/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.7185
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1831 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8409/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.9605
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1807 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8410/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.2312
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1843 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8411/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.8128
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1848 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8412/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.2734
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1764 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8413/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.0204
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1831 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8414/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.1163
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1817 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8415/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.4572
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1858 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8416/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.284
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1737 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8417/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.8712
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1738 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8418/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.9059
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1863 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8419/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.8405
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1849 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8420/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.8691
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1845 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8421/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.0299
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1809 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8422/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.0086
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1795 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8423/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.5708
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1796 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8424/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.3789
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1831 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8425/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.1954
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1836 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8426/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2456
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1734 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8427/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2343
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1753 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8428/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2989
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1809 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8429/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.1221
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1684 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8430/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2667
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1830 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8431/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2912
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1794 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8432/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.3355
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1818 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8433/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2573
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1812 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8434/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2536
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1732 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8435/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2787
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1767 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8436/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.3403
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1818 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8437/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.5716
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1814 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8438/100000]
# | D(G(z)): 0.0
# | D(x): 0.9846
# | errD: 0.0651
# | errG: 3.5326
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1732 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8439/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.7157
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1737 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8440/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.1746
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1758 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8441/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.7317
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1838 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8442/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.0208
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1828 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8443/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.7491
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1819 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8444/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2582
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1794 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8445/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.7965
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1830 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8446/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.9426
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1808 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8447/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.1662
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1745 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8448/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.0874
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1869 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8449/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.892
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1818 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8450/100000]
# | D(G(z)): 0.0001
# | D(x): 1.0
# | errD: 0.0001
# | errG: 17.1807
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1836 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8451/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.3323
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1736 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8452/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.3799
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1780 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8453/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.2274
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1798 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8454/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.5606
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1762 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8455/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.3862
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1776 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8456/100000]
# | D(G(z)): 0.0069
# | D(x): 1.0
# | errD: 0.0089
# | errG: 18.1269
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1781 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8457/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2621
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1803 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8458/100000]
# | D(G(z)): 0.0056
# | D(x): 1.0
# | errD: 0.0061
# | errG: 15.7576
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1757 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8459/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 15.5737
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1762 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8460/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 15.8249
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1786 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8461/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 15.6707
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1947 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8462/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 15.8791
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1766 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8463/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.4417
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1834 sec/idx)
# INFO: [Epoch 10/127][Global Step: 8464/100000]
# | D(G(z)): 0.0001
# | D(x): 0.9995
# | errD: 0.0006
# | errG: 15.2357
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1847 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8978/100000]
# | D(G(z)): 0.0001
# | D(x): 1.0
# | errD: 0.0001
# | errG: 16.1908
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1781 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8979/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.5916
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1874 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8980/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 16.2691
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1811 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8981/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 15.9057
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1803 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8982/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.6305
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1801 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8983/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.4015
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1893 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8984/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.344
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1780 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8985/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.0056
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1741 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8986/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.3461
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1726 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8987/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.2694
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1796 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8988/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.3126
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1812 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8989/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.3585
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1827 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8990/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.3408
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1776 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8991/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.3633
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1821 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8992/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.2518
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1816 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8993/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.2291
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1823 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8994/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.4923
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1890 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8995/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.495
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1897 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8996/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.4356
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1811 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8997/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.6464
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1880 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8998/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.0618
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1927 sec/idx)
# INFO: [Epoch 11/127][Global Step: 8999/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.8018
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1795 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9000/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.7667
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1773 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9001/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.8521
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.4905 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9002/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.7027
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1772 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9003/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.3391
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1806 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9004/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.2988
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1848 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9005/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.4193
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1833 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9006/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 18.4201
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.2006 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9007/100000]
# | D(G(z)): 0.0
# | D(x): 0.9995
# | errD: 0.0005
# | errG: 12.122
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1793 sec/idx)
# INFO: [Epoch 11/127][Global Step: 9008/100000]
# | D(G(z)): 0.0
# | D(x): 1.0
# | errD: 0.0
# | errG: 17.5053
# | lr_D: 0.0002
# | lr_G: 0.0002
# | (1.1838 sec/idx)

# %%
#########################
#        Training
#########################
# Start training
# trainer = mmc.training.Trainer(
#     netD=netD,
#     netG=netG,
#     optD=optD,
#     optG=optG,
#     n_dis=cfg.training.n_dis,
#     num_steps=cfg.training.num_steps,
#     dataloader=dataloader,
#     log_dir=cfg.logging.log_dir,
#     device=device)
# trainer.train()


##########################
#       Evaluation
##########################
# Evaluate fid
# mmc.metrics.evaluate(
#     metric="fid",
#     log_dir=cfg.logging.log_dir,
#     netG=netG,
#     dataset_name=cfg.dataset.dataset_name,
#     num_real_samples=cfg.metrics.fid.num_real_samples,
#     num_fake_samples=cfg.metrics.fid.num_fake_samples,
#     evaluate_step=cfg.metrics.fid.evaluate_step,
#     device=device)
mmc.metrics.evaluate(
    metric="fid",
    log_dir="logs",
    netG=netG,
    dataset_name="cifar10",
    num_real_samples=50000,
    num_fake_samples=50000,
    evaluate_step=100000,
    device=device)

# Evaluate inception score
# mmc.metrics.evaluate(
#     metric='inception_score',
#     log_dir=cfg.logging.log_dir,
#     netG=netG,
#     num_samples=cfg.metrics.inception_score.num_samples,
#     evaluate_step=cfg.metrics.inception_score.evaluate_step,
#     device=device)
mmc.metrics.evaluate(
    metric='inception_score',
    log_dir="logs",
    netG=netG,
    num_samples=50000,
    evaluate_step=100000,
    device=device)

# Evaluate kid
# mmc.metrics.evaluate(
#     metric='kid',
#     log_dir=cfg.logging.log_dir,
#     netG=netG,
#     dataset_name=cfg.dataset.dataset_name,
#     num_subsets=cfg.metrics.kid.num_subsets,
#     subset_size=cfg.metrics.kid.subset_size,
#     evaluate_step=cfg.metrics.kid.evaluate_step,
#     device=device)
# mmc.metrics.evaluate(
#     metric='kid',
#     log_dir="logs",
#     netG=netG,
#     dataset_name="cifar10",
#     num_subsets=50,
#     subset_size=1000,
#     evaluate_step=100000,
#     device=device)
# Out:
# INFO: Checkpoint at step 100000 does not exist. Skipping...
# INFO: FID Evaluation completed!
# INFO: Checkpoint at step 100000 does not exist. Skipping...
# INFO: Inception Score Evaluation completed!
# {}
